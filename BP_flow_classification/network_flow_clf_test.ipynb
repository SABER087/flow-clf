# %%
import pandas as pd
import csv
# read CSV file directly from a URL and save the results
# NOT: First extract zip file
#data = pd.read_csv('NISM.csv',   quoting=csv.QUOTE_NONE, encoding='utf-8')
data = pd.read_csv('ourdataset_test_small3.csv',   quoting=csv.QUOTE_NONE, encoding='utf-8')

#families whose count is greater than 30 
#class_group = df.groupby("class")

print(data.groupby('label').size())

# extact features and labels
# X feature set, y labels
X = data.loc[:,data.columns[:-1]] # -1 label kolonunu refer ediyor
y = data.label
X = X.values

print(X.shape)
# print X
# print '----------------------------------------------'

# Generally, this is one of the most commonly used preprocessing step.
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn import preprocessing

clf = ExtraTreesClassifier()
clf = clf.fit(X, y)
#print(clf.feature_importances_)

model = SelectFromModel(clf, prefit=True)
X_new = model.transform(X)
X=X_new
print(X.shape)
# print X

from sklearn import linear_model, ensemble, svm, ensemble, tree, neural_network, metrics, naive_bayes
from sklearn import cross_validation


# cross validation of the ML algorithms
def stratified_cv(X, y, clf_class, shuffle=True, n_folds=10, **kwargs):
    stratified_k_fold = cross_validation.StratifiedKFold(y, n_folds=n_folds, shuffle=shuffle)
    y_pred = y.copy()
#     print stratified_k_fold
#     print y_pred
    # ii+jj 的长度是样本总数，而 ii 表示用于训练的样本的序号集合，jj表示用于测试/预测的样本的序号集合
    for ii, jj in stratified_k_fold:
        X_train, X_test = X[ii], X[jj]
        y_train = y[ii]
        print 'ii= ',ii
        print 'len= ',len(ii)
        print 'jj= ',jj
        print 'len= ',len(jj)
        print 'X_train= ',X_train
        print 'X_test= ',X_test
        print 'y_train= ',y_train
        print 'y_train_len= ',len(y_train) 
        clf = clf_class(**kwargs)
        clf.fit(X_train,y_train)
        y_pred[jj] = clf.predict(X_test)
#         print 'y_pred    ',y_pred[jj]
    return y_pred

# print accuracies of the ML algo.
# print('Random Forest Classifier:       {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, ensemble.RandomForestClassifier))))
# print('Support vector machine(SVM):   {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, svm.SVC))))
# print('Logistic Regression:            {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, linear_model.LogisticRegression))))
print('Native Network:            {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, neural_network.MLPClassifier, activation ='relu',
                                                                                        hidden_layer_sizes =(30,30,30,30,30,30,30,30,30)))))
print 'finish'
# Out:
# label
# mail          308
# skype         281
# ssh           319
# teamviewer    336
# telegram      279
# dtype: int64
# (1523L, 22L)
# (1523L, 9L)
# ii=  [   1    2    3 ..., 1520 1521 1522]
# len=  1369
# jj=  [   0    6    7   13   16   17   34   40   45   60   62   83  109  120  122
#   144  164  173  185  191  208  214  220  238  247  253  254  259  260  282
#   285  295  326  334  336  338  341  343  350  351  384  399  425  435  446
#   455  471  492  500  508  509  511  514  561  562  566  568  580  583  625
#   637  645  660  676  677  706  713  714  728  730  736  738  756  761  764
#   781  799  813  829  837  843  850  855  864  891  892  894  900  902  921
#   922  923  927  953  959  966  984  992 1003 1006 1024 1026 1030 1032 1033
#  1035 1039 1040 1049 1066 1069 1071 1082 1085 1112 1114 1135 1150 1151 1157
#  1160 1167 1180 1181 1192 1201 1235 1240 1263 1289 1290 1303 1314 1345 1347
#  1355 1374 1377 1378 1385 1393 1400 1408 1423 1432 1434 1435 1437 1442 1473
#  1487 1488 1500 1515]
# len=  154
# X_train=  [[   150    557    187 ...,     54  34793      7]
#  [    94    246     81 ...,    607  18106      9]
#  [   169    978    263 ...,    549   9940     14]
#  ...,
#  [   175    639    242 ...,    200 139624      8]
#  [   297    735    306 ...,    421 125754     33]
#  [   321    703    314 ...,    264 167018     26]]
# X_test=  [[    95    247     81 ...,    591  25622     10]
#  [    94    246     81 ...,    558  44813     12]
#  [    94    246     81 ...,    607  21139      9]
#  ...,
#  [   132    557    189 ...,     64  37363      6]
#  [   132    557    189 ...,     55  66127      8]
#  [   307    735    316 ...,    256 143313     11]]
# y_train=  1           mail
# 2           mail
# 3           mail
# 4           mail
# 5           mail
# 8           mail
# 9           mail
# 10          mail
# 11          mail
# 12          mail
# 14          mail
# 15          mail
# 18          mail
# 19          mail
# 20          mail
# 21          mail
# 22          mail
# 23          mail
# 24          mail
# 25          mail
# 26          mail
# 27          mail
# 28          mail
# 29          mail
# 30          mail
# 31          mail
# 32          mail
# 33          mail
# 35          mail
# 36          mail
#           ...
# 1491    telegram
# 1492    telegram
# 1493    telegram
# 1494    telegram
# 1495    telegram
# 1496    telegram
# 1497    telegram
# 1498    telegram
# 1499    telegram
# 1501    telegram
# 1502    telegram
# 1503    telegram
# 1504    telegram
# 1505    telegram
# 1506    telegram
# 1507    telegram
# 1508    telegram
# 1509    telegram
# 1510    telegram
# 1511    telegram
# 1512    telegram
# 1513    telegram
# 1514    telegram
# 1516    telegram
# 1517    telegram
# 1518    telegram
# 1519    telegram
# 1520    telegram
# 1521    telegram
# 1522    telegram
# Name: label, Length: 1369, dtype: object
# y_train_len=  1369
# ii=  [   0    2    3 ..., 1520 1521 1522]
# len=  1370
# jj=  [   1    5   25   29   33   64   70   72   85   88  113  128  134  149  156
#   157  186  202  231  237  256  261  266  273  288  289  292  297  311  320
#   323  324  328  339  346  354  386  407  411  418  430  432  478  482  488
#   495  496  498  502  505  516  520  535  557  564  572  575  579  582  620
#   627  643  644  647  671  683  705  725  733  773  778  780  784  788  793
#   812  818  826  838  841  846  858  883  886  889  916  937  939  946  955
#   957  960  969  970  974  976  986  988  997 1001 1008 1010 1019 1022 1041
#  1070 1080 1089 1103 1131 1134 1158 1159 1163 1172 1200 1211 1214 1215 1224
#  1225 1229 1230 1236 1249 1258 1269 1273 1275 1283 1284 1291 1298 1332 1353
#  1358 1365 1436 1438 1439 1441 1454 1456 1458 1460 1465 1468 1475 1476 1489
#  1497 1510 1514]
# len=  153
# X_train=  [[    95    247     81 ...,    591  25622     10]
#  [    94    246     81 ...,    607  18106      9]
#  [   169    978    263 ...,    549   9940     14]
#  ...,
#  [   175    639    242 ...,    200 139624      8]
#  [   297    735    306 ...,    421 125754     33]
#  [   321    703    314 ...,    264 167018     26]]
# X_test=  [[   150    557    187 ...,     54  34793      7]
#  [   150    557    187 ...,     54  16853      7]
#  [   167    557    184 ...,     63  28105     13]
#  ...,
#  [   333    735    312 ...,    268 152766     49]
#  [    99    323    125 ...,     41    599      5]
#  [   132    557    189 ...,     64  42271      6]]
# y_train=  0           mail
# 2           mail
# 3           mail
# 4           mail
# 6           mail
# 7           mail
# 8           mail
# 9           mail
# 10          mail
# 11          mail
# 12          mail
# 13          mail
# 14          mail
# 15          mail
# 16          mail
# 17          mail
# 18          mail
# 19          mail
# 20          mail
# 21          mail
# 22          mail
# 23          mail
# 24          mail
# 26          mail
# 27          mail
# 28          mail
# 30          mail
# 31          mail
# 32          mail
# 34          mail
#           ...
# 1490    telegram
# 1491    telegram
# 1492    telegram
# 1493    telegram
# 1494    telegram
# 1495    telegram
# 1496    telegram
# 1498    telegram
# 1499    telegram
# 1500    telegram
# 1501    telegram
# 1502    telegram
# 1503    telegram
# 1504    telegram
# 1505    telegram
# 1506    telegram
# 1507    telegram
# 1508    telegram
# 1509    telegram
# 1511    telegram
# 1512    telegram
# 1513    telegram
# 1515    telegram
# 1516    telegram
# 1517    telegram
# 1518    telegram
# 1519    telegram
# 1520    telegram
# 1521    telegram
# 1522    telegram
# Name: label, Length: 1370, dtype: object
# y_train_len=  1370
# ii=  [   0    1    2 ..., 1519 1521 1522]
# len=  1370
# jj=  [  12   26   37   43   51   73   76   86  106  114  126  127  131  132  148
#   153  166  183  194  210  213  222  223  224  230  232  248  252  257  264
#   284  286  348  353  355  361  368  389  397  401  410  412  417  438  442
#   450  457  465  466  494  523  555  563  565  569  571  596  605  611  614
#   615  618  623  630  641  655  667  670  678  681  684  715  719  720  721
#   739  759  767  787  789  790  794  801  805  806  849  851  860  866  882
#   885  888  890  898  901  911  926  930  972 1002 1011 1020 1034 1044 1075
#  1081 1097 1100 1111 1118 1122 1141 1146 1153 1155 1184 1186 1195 1206 1207
#  1245 1250 1252 1253 1256 1259 1267 1270 1302 1315 1326 1346 1356 1357 1360
#  1362 1370 1411 1421 1463 1464 1474 1477 1480 1481 1485 1496 1499 1501 1506
#  1508 1518 1520]
# len=  153
# X_train=  [[    95    247     81 ...,    591  25622     10]
#  [   150    557    187 ...,     54  34793      7]
#  [    94    246     81 ...,    607  18106      9]
#  ...,
#  [   132    557    189 ...,     64  37363      6]
#  [   297    735    306 ...,    421 125754     33]
#  [   321    703    314 ...,    264 167018     26]]
# X_test=  [[    99    238     79 ...,    579  13030     10]
#  [   161    557    184 ...,     74  20975     10]
#  [   144    557    162 ...,    109  21154     12]
#  ...,
#  [    69    235     73 ...,    676   1415      7]
#  [    88    273     86 ...,    595  39917     11]
#  [   175    639    242 ...,    200 139624      8]]
# y_train=  0           mail
# 1           mail
# 2           mail
# 3           mail
# 4           mail
# 5           mail
# 6           mail
# 7           mail
# 8           mail
# 9           mail
# 10          mail
# 11          mail
# 13          mail
# 14          mail
# 15          mail
# 16          mail
# 17          mail
# 18          mail
# 19          mail
# 20          mail
# 21          mail
# 22          mail
# 23          mail
# 24          mail
# 25          mail
# 27          mail
# 28          mail
# 29          mail
# 30          mail
# 31          mail
#           ...
# 1486    telegram
# 1487    telegram
# 1488    telegram
# 1489    telegram
# 1490    telegram
# 1491    telegram
# 1492    telegram
# 1493    telegram
# 1494    telegram
# 1495    telegram
# 1497    telegram
# 1498    telegram
# 1500    telegram
# 1502    telegram
# 1503    telegram
# 1504    telegram
# 1505    telegram
# 1507    telegram
# 1509    telegram
# 1510    telegram
# 1511    telegram
# 1512    telegram
# 1513    telegram
# 1514    telegram
# 1515    telegram
# 1516    telegram
# 1517    telegram
# 1519    telegram
# 1521    telegram
# 1522    telegram
# Name: label, Length: 1370, dtype: object
# y_train_len=  1370
# ii=  [   0    1    2 ..., 1520 1521 1522]
# len=  1370
# jj=  [   9   11   20   22   30   31   35   52   67   84   92   97   99  117  123
#   129  130  137  140  178  181  190  207  234  241  268  269  272  277  278
#   279  280  281  298  306  312  329  359  371  379  380  383  385  394  403
#   419  426  439  441  443  464  499  529  531  536  538  547  570  576  584
#   592  594  595  608  612  617  626  650  662  663  669  672  692  695  708
#   710  722  740  769  770  774  776  777  796  797  815  821  827  874  897
#   903  907  931  933  934  936  941  942  948  956  975  977  983 1012 1017
#  1051 1052 1056 1068 1072 1076 1077 1079 1099 1101 1106 1129 1143 1144 1148
#  1152 1161 1162 1173 1182 1196 1223 1234 1239 1242 1297 1301 1312 1317 1319
#  1321 1337 1339 1340 1344 1348 1375 1376 1381 1401 1407 1414 1425 1452 1466
#  1509 1511 1517]
# len=  153
# X_train=  [[    95    247     81 ...,    591  25622     10]
#  [   150    557    187 ...,     54  34793      7]
#  [    94    246     81 ...,    607  18106      9]
#  ...,
#  [   175    639    242 ...,    200 139624      8]
#  [   297    735    306 ...,    421 125754     33]
#  [   321    703    314 ...,    264 167018     26]]
# X_test=  [[   94   246    81 ...,   607 14355     9]
#  [  127   411   119 ...,   524 12545    13]
#  [   90   247    79 ...,   558 42293    12]
#  ...,
#  [   76   244    82 ...,   546 12666     5]
#  [  154   365   141 ...,   530 11471    20]
#  [  245   655   283 ...,   220 34204     5]]
# y_train=  0           mail
# 1           mail
# 2           mail
# 3           mail
# 4           mail
# 5           mail
# 6           mail
# 7           mail
# 8           mail
# 10          mail
# 12          mail
# 13          mail
# 14          mail
# 15          mail
# 16          mail
# 17          mail
# 18          mail
# 19          mail
# 21          mail
# 23          mail
# 24          mail
# 25          mail
# 26          mail
# 27          mail
# 28          mail
# 29          mail
# 32          mail
# 33          mail
# 34          mail
# 36          mail
#           ...
# 1490    telegram
# 1491    telegram
# 1492    telegram
# 1493    telegram
# 1494    telegram
# 1495    telegram
# 1496    telegram
# 1497    telegram
# 1498    telegram
# 1499    telegram
# 1500    telegram
# 1501    telegram
# 1502    telegram
# 1503    telegram
# 1504    telegram
# 1505    telegram
# 1506    telegram
# 1507    telegram
# 1508    telegram
# 1510    telegram
# 1512    telegram
# 1513    telegram
# 1514    telegram
# 1515    telegram
# 1516    telegram
# 1518    telegram
# 1519    telegram
# 1520    telegram
# 1521    telegram
# 1522    telegram
# Name: label, Length: 1370, dtype: object
# y_train_len=  1370
# ii=  [   0    1    2 ..., 1520 1521 1522]
# len=  1370
# jj=  [  39   41   42   44   53   57   58   61   69   77   79   93  100  105  111
#   115  119  125  133  143  147  151  159  163  170  179  192  195  244  265
#   274  305  313  316  337  340  357  363  364  367  372  375  376  381  382
#   395  398  408  416  427  433  436  444  449  456  458  461  477  480  487
#   497  517  521  528  548  591  598  607  613  624  638  648  651  661  664
#   688  709  712  716  718  724  729  741  742  749  753  762  791  807  819
#   820  845  852  861  878  949  951  964  968  971  979  980  981  985  989
#   991 1016 1023 1027 1050 1062 1073 1092 1094 1102 1110 1120 1124 1164 1170
#  1188 1193 1197 1202 1213 1226 1227 1243 1246 1292 1294 1310 1334 1341 1350
#  1351 1368 1398 1399 1404 1405 1406 1417 1426 1430 1457 1491 1495 1498 1503
#  1504 1512 1513]
# len=  153
# X_train=  [[    95    247     81 ...,    591  25622     10]
#  [   150    557    187 ...,     54  34793      7]
#  [    94    246     81 ...,    607  18106      9]
#  ...,
#  [   175    639    242 ...,    200 139624      8]
#  [   297    735    306 ...,    421 125754     33]
#  [   321    703    314 ...,    264 167018     26]]
# X_test=  [[  290   877   352 ...,   615 51080     7]
#  [   90   247    79 ...,   591 27018    10]
#  [  127   557   170 ...,    54 11564     7]
#  ...,
#  [   96   639   149 ...,   496 24620    20]
#  [  168   671   242 ...,   196 65964    18]
#  [  240   877   328 ...,   595 51880     9]]
# y_train=  0           mail
# 1           mail
# 2           mail
# 3           mail
# 4           mail
# 5           mail
# 6           mail
# 7           mail
# 8           mail
# 9           mail
# 10          mail
# 11          mail
# 12          mail
# 13          mail
# 14          mail
# 15          mail
# 16          mail
# 17          mail
# 18          mail
# 19          mail
# 20          mail
# 21          mail
# 22          mail
# 23          mail
# 24          mail
# 25          mail
# 26          mail
# 27          mail
# 28          mail
# 29          mail
#           ...
# 1486    telegram
# 1487    telegram
# 1488    telegram
# 1489    telegram
# 1490    telegram
# 1492    telegram
# 1493    telegram
# 1494    telegram
# 1496    telegram
# 1497    telegram
# 1499    telegram
# 1500    telegram
# 1501    telegram
# 1502    telegram
# 1505    telegram
# 1506    telegram
# 1507    telegram
# 1508    telegram
# 1509    telegram
# 1510    telegram
# 1511    telegram
# 1514    telegram
# 1515    telegram
# 1516    telegram
# 1517    telegram
# 1518    telegram
# 1519    telegram
# 1520    telegram
# 1521    telegram
# 1522    telegram
# Name: label, Length: 1370, dtype: object
# y_train_len=  1370
# ii=  [   0    1    2 ..., 1519 1520 1521]
# len=  1370
# jj=  [   3   10   27   47   50   55   87   96  116  139  162  165  176  196  201
#   211  212  221  227  228  229  236  246  251  270  271  276  287  291  304
#   315  319  330  332  388  390  396  405  437  451  454  462  468  501  510
#   512  532  537  541  542  558  560  574  590  593  599  621  622  629  633
#   634  639  642  666  679  682  685  694  700  723  731  735  746  751  752
#   754  755  760  779  785  824  828  842  856  879  881  887  893  895  896
#   904  906  940  945  954  982  993  995  996 1004 1007 1014 1021 1042 1045
#  1047 1064 1084 1149 1156 1168 1169 1175 1176 1203 1212 1232 1233 1244 1247
#  1248 1251 1260 1261 1262 1274 1277 1300 1305 1325 1330 1331 1354 1359 1361
#  1364 1380 1382 1388 1396 1440 1443 1446 1451 1459 1470 1471 1484 1486 1490
#  1492 1516 1522]
# len=  153
# X_train=  [[    95    247     81 ...,    591  25622     10]
#  [   150    557    187 ...,     54  34793      7]
#  [    94    246     81 ...,    607  18106      9]
#  ...,
#  [   132    557    189 ...,     64  37363      6]
#  [   175    639    242 ...,    200 139624      8]
#  [   297    735    306 ...,    421 125754     33]]
# X_test=  [[   169    978    263 ...,    549   9940     14]
#  [    94    246     81 ...,    591  22181     10]
#  [   150    915    240 ...,    517  17133     17]
#  ...,
#  [   238    703    294 ...,    225 203409     12]
#  [   239    623    273 ...,    204 127285      6]
#  [   321    703    314 ...,    264 167018     26]]
# y_train=  0           mail
# 1           mail
# 2           mail
# 4           mail
# 5           mail
# 6           mail
# 7           mail
# 8           mail
# 9           mail
# 11          mail
# 12          mail
# 13          mail
# 14          mail
# 15          mail
# 16          mail
# 17          mail
# 18          mail
# 19          mail
# 20          mail
# 21          mail
# 22          mail
# 23          mail
# 24          mail
# 25          mail
# 26          mail
# 28          mail
# 29          mail
# 30          mail
# 31          mail
# 32          mail
#           ...
# 1489    telegram
# 1491    telegram
# 1493    telegram
# 1494    telegram
# 1495    telegram
# 1496    telegram
# 1497    telegram
# 1498    telegram
# 1499    telegram
# 1500    telegram
# 1501    telegram
# 1502    telegram
# 1503    telegram
# 1504    telegram
# 1505    telegram
# 1506    telegram
# 1507    telegram
# 1508    telegram
# 1509    telegram
# 1510    telegram
# 1511    telegram
# 1512    telegram
# 1513    telegram
# 1514    telegram
# 1515    telegram
# 1517    telegram
# 1518    telegram
# 1519    telegram
# 1520    telegram
# 1521    telegram
# Name: label, Length: 1370, dtype: object
# y_train_len=  1370
# ii=  [   0    1    3 ..., 1520 1521 1522]
# len=  1371
# jj=  [   2    8   38   56   63   66   71   80   81   94   95  103  110  121  136
#   142  146  150  160  169  177  182  216  226  235  243  258  263  267  302
#   308  310  318  325  352  358  366  374  391  406  428  431  434  447  463
#   474  481  483  486  490  513  515  530  533  544  552  573  586  587  589
#   597  601  610  616  628  653  668  675  686  732  748  758  768  786  803
#   814  823  831  833  834  836  840  844  867  870  873  875  876  880  899
#   909  914  925  935  944  958  961  973  994  998  999 1013 1015 1018 1025
#  1031 1057 1074 1098 1107 1113 1116 1119 1121 1123 1137 1140 1154 1165 1177
#  1183 1185 1187 1189 1217 1241 1254 1266 1280 1295 1296 1299 1320 1328 1329
#  1335 1373 1387 1390 1392 1394 1395 1402 1412 1418 1422 1427 1431 1444 1449
#  1469 1479]
# len=  152
# X_train=  [[    95    247     81 ...,    591  25622     10]
#  [   150    557    187 ...,     54  34793      7]
#  [   169    978    263 ...,    549   9940     14]
#  ...,
#  [   175    639    242 ...,    200 139624      8]
#  [   297    735    306 ...,    421 125754     33]
#  [   321    703    314 ...,    264 167018     26]]
# X_test=  [[   94   246    81 ...,   607 18106     9]
#  [  131   557   167 ...,    49 17688     9]
#  [   95   247    81 ...,   607 20321     9]
#  ...,
#  [  154   365   141 ...,   530 11471    20]
#  [  132   557   189 ...,    55 66127     8]
#  [   99   323   125 ...,    41   599     5]]
# y_train=  0           mail
# 1           mail
# 3           mail
# 4           mail
# 5           mail
# 6           mail
# 7           mail
# 9           mail
# 10          mail
# 11          mail
# 12          mail
# 13          mail
# 14          mail
# 15          mail
# 16          mail
# 17          mail
# 18          mail
# 19          mail
# 20          mail
# 21          mail
# 22          mail
# 23          mail
# 24          mail
# 25          mail
# 26          mail
# 27          mail
# 28          mail
# 29          mail
# 30          mail
# 31          mail
#           ...
# 1493    telegram
# 1494    telegram
# 1495    telegram
# 1496    telegram
# 1497    telegram
# 1498    telegram
# 1499    telegram
# 1500    telegram
# 1501    telegram
# 1502    telegram
# 1503    telegram
# 1504    telegram
# 1505    telegram
# 1506    telegram
# 1507    telegram
# 1508    telegram
# 1509    telegram
# 1510    telegram
# 1511    telegram
# 1512    telegram
# 1513    telegram
# 1514    telegram
# 1515    telegram
# 1516    telegram
# 1517    telegram
# 1518    telegram
# 1519    telegram
# 1520    telegram
# 1521    telegram
# 1522    telegram
# Name: label, Length: 1371, dtype: object
# y_train_len=  1371
# ii=  [   0    1    2 ..., 1518 1520 1522]
# len=  1371
# jj=  [   4   24   36   46   48   78   90  101  104  107  108  112  118  135  168
#   171  180  184  187  197  209  240  242  245  262  293  294  301  307  322
#   335  349  356  360  362  370  378  387  404  413  414  429  452  453  459
#   467  470  475  479  503  504  525  526  546  549  551  567  581  585  602
#   632  640  646  649  659  665  673  674  687  693  696  698  699  704  707
#   711  757  771  782  800  804  808  810  825  830  832  847  853  863  869
#   905  908  919  924  932  950  962  965  990 1029 1036 1037 1038 1048 1059
#  1083 1093 1104 1109 1125 1127 1133 1142 1145 1174 1198 1199 1204 1205 1208
#  1210 1237 1257 1265 1268 1279 1281 1285 1288 1306 1309 1311 1336 1338 1343
#  1349 1352 1366 1369 1379 1386 1415 1424 1447 1453 1455 1472 1493 1502 1507
#  1519 1521]
# len=  152
# X_train=  [[    95    247     81 ...,    591  25622     10]
#  [   150    557    187 ...,     54  34793      7]
#  [    94    246     81 ...,    607  18106      9]
#  ...,
#  [    88    273     86 ...,    595  39917     11]
#  [   175    639    242 ...,    200 139624      8]
#  [   321    703    314 ...,    264 167018     26]]
# X_test=  [[    94    246     81 ...,    607  19489      9]
#  [   150    557    187 ...,     54  27698      7]
#  [   150    557    187 ...,     54  27064      7]
#  ...,
#  [    99    323    125 ...,     46   1063      4]
#  [   132    557    189 ...,     64  37363      6]
#  [   297    735    306 ...,    421 125754     33]]
# y_train=  0           mail
# 1           mail
# 2           mail
# 3           mail
# 5           mail
# 6           mail
# 7           mail
# 8           mail
# 9           mail
# 10          mail
# 11          mail
# 12          mail
# 13          mail
# 14          mail
# 15          mail
# 16          mail
# 17          mail
# 18          mail
# 19          mail
# 20          mail
# 21          mail
# 22          mail
# 23          mail
# 25          mail
# 26          mail
# 27          mail
# 28          mail
# 29          mail
# 30          mail
# 31          mail
#           ...
# 1488    telegram
# 1489    telegram
# 1490    telegram
# 1491    telegram
# 1492    telegram
# 1494    telegram
# 1495    telegram
# 1496    telegram
# 1497    telegram
# 1498    telegram
# 1499    telegram
# 1500    telegram
# 1501    telegram
# 1503    telegram
# 1504    telegram
# 1505    telegram
# 1506    telegram
# 1508    telegram
# 1509    telegram
# 1510    telegram
# 1511    telegram
# 1512    telegram
# 1513    telegram
# 1514    telegram
# 1515    telegram
# 1516    telegram
# 1517    telegram
# 1518    telegram
# 1520    telegram
# 1522    telegram
# Name: label, Length: 1371, dtype: object
# y_train_len=  1371
# ii=  [   0    1    2 ..., 1520 1521 1522]
# len=  1372
# jj=  [  14   59   68   74   82   89   98  102  138  152  155  161  167  174  175
#   189  198  199  203  205  215  218  225  233  249  283  290  296  303  314
#   317  347  365  373  393  400  402  415  421  422  440  445  448  472  473
#   476  484  491  506  518  524  527  540  543  550  553  556  559  578  600
#   604  606  609  635  636  654  657  658  680  689  690  691  702  717  743
#   744  747  763  765  766  775  792  798  809  816  822  835  848  854  857
#   868  871  910  918  928  929  952  963  978 1000 1009 1028 1043 1053 1054
#  1055 1063 1065 1067 1087 1090 1126 1130 1136 1138 1147 1178 1179 1190 1194
#  1209 1218 1222 1228 1231 1238 1271 1282 1293 1304 1307 1318 1322 1323 1333
#  1342 1363 1367 1371 1383 1384 1397 1419 1420 1429 1433 1445 1448 1467 1482
#  1483]
# len=  151
# X_train=  [[    95    247     81 ...,    591  25622     10]
#  [   150    557    187 ...,     54  34793      7]
#  [    94    246     81 ...,    607  18106      9]
#  ...,
#  [   175    639    242 ...,    200 139624      8]
#  [   297    735    306 ...,    421 125754     33]
#  [   321    703    314 ...,    264 167018     26]]
# X_test=  [[   112    392    107 ...,    579  27905     14]
#  [   140    921    224 ...,    555  14520     24]
#  [    90    247     79 ...,    558  45077     12]
#  ...,
#  [   444    719    289 ...,    273 124363     69]
#  [   240    877    328 ...,    595  51880      9]
#  [   132    557    189 ...,     64  42271      6]]
# y_train=  0           mail
# 1           mail
# 2           mail
# 3           mail
# 4           mail
# 5           mail
# 6           mail
# 7           mail
# 8           mail
# 9           mail
# 10          mail
# 11          mail
# 12          mail
# 13          mail
# 15          mail
# 16          mail
# 17          mail
# 18          mail
# 19          mail
# 20          mail
# 21          mail
# 22          mail
# 23          mail
# 24          mail
# 25          mail
# 26          mail
# 27          mail
# 28          mail
# 29          mail
# 30          mail
#           ...
# 1493    telegram
# 1494    telegram
# 1495    telegram
# 1496    telegram
# 1497    telegram
# 1498    telegram
# 1499    telegram
# 1500    telegram
# 1501    telegram
# 1502    telegram
# 1503    telegram
# 1504    telegram
# 1505    telegram
# 1506    telegram
# 1507    telegram
# 1508    telegram
# 1509    telegram
# 1510    telegram
# 1511    telegram
# 1512    telegram
# 1513    telegram
# 1514    telegram
# 1515    telegram
# 1516    telegram
# 1517    telegram
# 1518    telegram
# 1519    telegram
# 1520    telegram
# 1521    telegram
# 1522    telegram
# Name: label, Length: 1372, dtype: object
# y_train_len=  1372
# ii=  [   0    1    2 ..., 1520 1521 1522]
# len=  1374
# jj=  [  15   18   19   21   23   28   32   49   54   65   75   91  124  141  145
#   154  158  172  188  193  200  204  206  217  219  239  250  255  275  299
#   300  309  321  327  331  333  342  344  345  369  377  392  409  420  423
#   424  460  469  485  489  493  507  519  522  534  539  545  554  577  588
#   603  619  631  652  656  697  701  703  726  727  734  737  745  750  772
#   783  795  802  811  817  839  859  862  865  872  877  884  912  913  915
#   917  920  938  943  947  967  987 1005 1046 1058 1060 1061 1078 1086 1088
#  1091 1095 1096 1105 1108 1115 1117 1128 1132 1139 1166 1171 1191 1216 1219
#  1220 1221 1255 1264 1272 1276 1278 1286 1287 1308 1313 1316 1324 1327 1372
#  1389 1391 1403 1409 1410 1413 1416 1428 1450 1461 1462 1478 1494 1505]
# len=  149
# X_train=  [[    95    247     81 ...,    591  25622     10]
#  [   150    557    187 ...,     54  34793      7]
#  [    94    246     81 ...,    607  18106      9]
#  ...,
#  [   175    639    242 ...,    200 139624      8]
#  [   297    735    306 ...,    421 125754     33]
#  [   321    703    314 ...,    264 167018     26]]
# X_test=  [[    94    246     81 ...,    591  23923     10]
#  [    95    247     81 ...,    591  24993     10]
#  [   150    557    187 ...,     54  20103      7]
#  ...,
#  [    76    244     82 ...,    546  12666      5]
#  [   316    719    315 ...,    264 151319     23]
#  [   132    557    189 ...,     64  37949      6]]
# y_train=  0           mail
# 1           mail
# 2           mail
# 3           mail
# 4           mail
# 5           mail
# 6           mail
# 7           mail
# 8           mail
# 9           mail
# 10          mail
# 11          mail
# 12          mail
# 13          mail
# 14          mail
# 16          mail
# 17          mail
# 20          mail
# 22          mail
# 24          mail
# 25          mail
# 26          mail
# 27          mail
# 29          mail
# 30          mail
# 31          mail
# 33          mail
# 34          mail
# 35          mail
# 36          mail
#           ...
# 1491    telegram
# 1492    telegram
# 1493    telegram
# 1495    telegram
# 1496    telegram
# 1497    telegram
# 1498    telegram
# 1499    telegram
# 1500    telegram
# 1501    telegram
# 1502    telegram
# 1503    telegram
# 1504    telegram
# 1506    telegram
# 1507    telegram
# 1508    telegram
# 1509    telegram
# 1510    telegram
# 1511    telegram
# 1512    telegram
# 1513    telegram
# 1514    telegram
# 1515    telegram
# 1516    telegram
# 1517    telegram
# 1518    telegram
# 1519    telegram
# 1520    telegram
# 1521    telegram
# 1522    telegram
# Name: label, Length: 1374, dtype: object
# y_train_len=  1374
# Native Network:            0.44
# finish
